# %%
import numpy as np
import pandas as pd

# %%
def dataProcess(path):
    
    def dirList2FloatList(dirList):
        direction = {'N': 0, 'E': 0.25, 'S': 0.5, 'W':0.75}
        floatList = []
        for s in dirList:
            if type(s) != str:
                floatList.append(s)
                continue
            num = direction[s[0]]
            for i in range(1, len(s)):
                if(s[i-1] == 'W' and s[i] == 'N'):
                    num = (num + 1) / 2
                else:
                    num = (num + direction[s[i]]) / 2
            floatList.append(num)
        return floatList


    def YesNo210(s):
        if s == 'No':
            return 0
        return 1
    
    
    
    
    data = pd.read_csv(path)
    data.drop(columns=['Attribute1', 'Attribute2', 'Attribute10', 'Attribute11', 'Attribute12', 'Attribute14'
                      ,'Attribute16', 'Attribute18', 'Attribute20'], inplace = True)
#     data['Attribute8'] = dirList2FloatList(data['Attribute8'])
    # data['Attribute10'] = dirList2FloatList(data['Attribute10'])
#     data['Attribute11'] = dirList2FloatList(data['Attribute11'])
    data['Attribute22'] = data['Attribute22'].apply(YesNo210)
    if 'Attribute23' in data.columns:
        data['Attribute23'] = data['Attribute23'].apply(YesNo210)
    
    data.describe()
    
    data.fillna(data.mean(), inplace = True)
    data = (data - data.min()) / (data.max() - data.min())
    
    return data

# %%
trainData = dataProcess('train.csv')
trainData.to_csv('train2.csv', index=None)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# D:\Program Files (x86)\Anaconda3\lib\site-packages\pandas\core\ops\__init__.py in na_op(x, y)
#     967         try:
# --> 968             result = expressions.evaluate(op, str_rep, x, y, **eval_kwargs)
#     969         except TypeError:
#
# D:\Program Files (x86)\Anaconda3\lib\site-packages\pandas\core\computation\expressions.py in evaluate(op, op_str, a, b, use_numexpr, **eval_kwargs)
#     220     if use_numexpr:
# --> 221         return _evaluate(op, op_str, a, b, **eval_kwargs)
#     222     return _evaluate_standard(op, op_str, a, b)
#
# D:\Program Files (x86)\Anaconda3\lib\site-packages\pandas\core\computation\expressions.py in _evaluate_numexpr(op, op_str, a, b, truediv, reversed, **eval_kwargs)
#     126     if result is None:
# --> 127         result = _evaluate_standard(op, op_str, a, b)
#     128
#
# D:\Program Files (x86)\Anaconda3\lib\site-packages\pandas\core\computation\expressions.py in _evaluate_standard(op, op_str, a, b, **eval_kwargs)
#      69     with np.errstate(all="ignore"):
# ---> 70         return op(a, b)
#      71
#
# TypeError: unsupported operand type(s) for -: 'str' and 'float'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-35-01e707737897> in <module>
# ----> 1 trainData = dataProcess('train.csv')
#       2 trainData.to_csv('train2.csv', index=None)
#
# <ipython-input-34-f33e4cbf189f> in dataProcess(path)
#      39
#      40     data.fillna(data.mean(), inplace = True)
# ---> 41     data = (data - data.min()) / (data.max() - data.min())
#      42
#      43     return data
#
# D:\Program Files (x86)\Anaconda3\lib\site-packages\pandas\core\ops\__init__.py in f(self, other, axis, level, fill_value)
#    1497             pass_op = op if axis in [0, "columns", None] else na_op
#    1498             return _combine_series_frame(
# -> 1499                 self, other, pass_op, fill_value=fill_value, axis=axis, level=level
#    1500             )
#    1501         else:
#
# D:\Program Files (x86)\Anaconda3\lib\site-packages\pandas\core\ops\__init__.py in _combine_series_frame(self, other, func, fill_value, axis, level)
#    1398
#    1399         # default axis is columns
# -> 1400         return self._combine_match_columns(other, func, level=level)
#    1401
#    1402
#
# D:\Program Files (x86)\Anaconda3\lib\site-packages\pandas\core\frame.py in _combine_match_columns(self, other, func, level)
#    5412         left, right = self.align(other, join="outer", axis=1, level=level, copy=False)
#    5413         assert left.columns.equals(right.index)
# -> 5414         return ops.dispatch_to_series(left, right, func, axis="columns")
#    5415
#    5416     def _combine_const(self, other, func):
#
# D:\Program Files (x86)\Anaconda3\lib\site-packages\pandas\core\ops\__init__.py in dispatch_to_series(left, right, func, str_rep, axis)
#     594         raise NotImplementedError(right)
#     595
# --> 596     new_data = expressions.evaluate(column_op, str_rep, left, right)
#     597
#     598     result = left._constructor(new_data, index=left.index, copy=False)
#
# D:\Program Files (x86)\Anaconda3\lib\site-packages\pandas\core\computation\expressions.py in evaluate(op, op_str, a, b, use_numexpr, **eval_kwargs)
#     219     use_numexpr = use_numexpr and _bool_arith_check(op_str, a, b)
#     220     if use_numexpr:
# --> 221         return _evaluate(op, op_str, a, b, **eval_kwargs)
#     222     return _evaluate_standard(op, op_str, a, b)
#     223
#
# D:\Program Files (x86)\Anaconda3\lib\site-packages\pandas\core\computation\expressions.py in _evaluate_numexpr(op, op_str, a, b, truediv, reversed, **eval_kwargs)
#     125
#     126     if result is None:
# --> 127         result = _evaluate_standard(op, op_str, a, b)
#     128
#     129     return result
#
# D:\Program Files (x86)\Anaconda3\lib\site-packages\pandas\core\computation\expressions.py in _evaluate_standard(op, op_str, a, b, **eval_kwargs)
#      68         _store_test_result(False)
#      69     with np.errstate(all="ignore"):
# ---> 70         return op(a, b)
#      71
#      72
#
# D:\Program Files (x86)\Anaconda3\lib\site-packages\pandas\core\ops\__init__.py in column_op(a, b)
#     582
#     583         def column_op(a, b):
# --> 584             return {i: func(a.iloc[:, i], b.iloc[i]) for i in range(len(a.columns))}
#     585
#     586     elif isinstance(right, ABCSeries):
#
# D:\Program Files (x86)\Anaconda3\lib\site-packages\pandas\core\ops\__init__.py in <dictcomp>(.0)
#     582
#     583         def column_op(a, b):
# --> 584             return {i: func(a.iloc[:, i], b.iloc[i]) for i in range(len(a.columns))}
#     585
#     586     elif isinstance(right, ABCSeries):
#
# D:\Program Files (x86)\Anaconda3\lib\site-packages\pandas\core\ops\__init__.py in wrapper(left, right)
#    1046
#    1047         with np.errstate(all="ignore"):
# -> 1048             result = na_op(lvalues, rvalues)
#    1049         return construct_result(
#    1050             left, result, index=left.index, name=res_name, dtype=None
#
# D:\Program Files (x86)\Anaconda3\lib\site-packages\pandas\core\ops\__init__.py in na_op(x, y)
#     968             result = expressions.evaluate(op, str_rep, x, y, **eval_kwargs)
#     969         except TypeError:
# --> 970             result = masked_arith_op(x, y, op)
#     971
#     972         return missing.dispatch_fill_zeros(op, x, y, result)
#
# D:\Program Files (x86)\Anaconda3\lib\site-packages\pandas\core\ops\__init__.py in masked_arith_op(x, y, op)
#     462         if mask.any():
#     463             with np.errstate(all="ignore"):
# --> 464                 result[mask] = op(xrav[mask], y)
#     465
#     466     result, changed = maybe_upcast_putmask(result, ~mask, np.nan)
#
# TypeError: unsupported operand type(s) for -: 'str' and 'float'

# %%
len(trainData.iloc[0])
# Out:
# 16

# %%
trainData
# Out:
#        Attribute2  Attribute3  Attribute4  Attribute5  Attribute6  Attribute7  \
# 0        0.041667    0.552972    0.516461    0.002774    0.038385    0.543445
# 1        0.041667    0.397933    0.561728    0.000000    0.038385    0.543445
# 2        0.041667    0.405685    0.594650    0.000000    0.038385    0.543445
# 3        0.041667    0.503876    0.648148    0.000000    0.038385    0.543445
# 4        0.041667    0.648579    0.724280    0.000000    0.038385    0.543445
# ...           ...         ...         ...         ...         ...         ...
# 17092    0.854167    0.527132    0.600823    0.000000    0.038385    0.543445
# 17093    0.854167    0.467700    0.594650    0.000000    0.038385    0.543445
# 17094    0.854167    0.351421    0.444444    0.000000    0.038385    0.543445
# 17095    0.854167    0.273902    0.508230    0.000000    0.038385    0.543445
# 17096    0.854167    0.299742    0.565844    0.000000    0.038385    0.543445
#
#        Attribute8  Attribute9  Attribute11  Attribute13  Attribute15  \
# 0        0.923077    0.310924     1.000000     0.307692         0.22
# 1        1.000000    0.310924     0.846154     0.282051         0.25
# 2        0.923077    0.235294     0.923077     0.217949         0.19
# 3        0.615385    0.142857     0.461538     0.115385         0.28
# 4        0.153846    0.302521     0.000000     0.282051         0.28
# ...           ...         ...          ...          ...          ...
# 17092    0.307692    0.344538     0.384615     0.256410         0.24
# 17093    0.307692    0.285714     0.307692     0.217949         0.29
# 17094    0.307692    0.302521     0.384615     0.307692         0.22
# 17095    0.615385    0.100840     0.307692     0.089744         0.24
# 17096    0.461538    0.126050     0.000000     0.115385         0.21
#
#        Attribute17  Attribute19  Attribute21  Attribute22  Attribute23
# 0         0.464158     0.545076     0.522727          0.0          0.0
# 1         0.476703     0.545076     0.574380          0.0          0.0
# 2         0.517921     0.545076     0.599174          0.0          0.0
# 3         0.602151     0.545076     0.636364          0.0          0.0
# 4         0.482079     0.125000     0.725207          0.0          0.0
# ...            ...          ...          ...          ...          ...
# 17092     0.639785     0.545076     0.617769          0.0          0.0
# 17093     0.670251     0.545076     0.603306          0.0          0.0
# 17094     0.822581     0.545076     0.450413          0.0          0.0
# 17095     0.720430     0.545076     0.528926          0.0          0.0
# 17096     0.679211     0.545076     0.578512          0.0          0.0
#
# [17097 rows x 16 columns]

# %%
testData = dataProcess('test.csv')
testData.to_csv('test2.csv', index=None)

# %%
t = pd.read_csv('test2.csv')

# %%
t
# Out:
#      Attribute2  Attribute3  Attribute4  Attribute5  Attribute6  Attribute7  \
# 0      0.155556    0.852201    0.948127    0.000000    0.520661    0.956522
# 1      0.155556    0.349057    0.149856    0.001188    0.090909    0.007246
# 2      0.155556    0.713836    0.855908    0.000000    0.264463    0.869565
# 3      0.155556    0.569182    0.625360    0.000000    0.214876    0.702899
# 4      0.155556    0.471698    0.262248    0.010689    0.024793    0.036232
# ..          ...         ...         ...         ...         ...         ...
# 819    0.222222    0.861635    0.763689    0.047506    0.157025    0.681159
# 820    0.222222    0.852201    0.743516    0.003563    0.123967    0.673913
# 821    0.222222    0.871069    0.766571    0.000000    0.297521    0.760870
# 822    0.222222    0.955975    0.743516    0.001188    0.280992    0.434783
# 823    0.222222    0.889937    0.752161    0.000000    0.181818    0.710145
#
#      Attribute8  Attribute9  Attribute11  Attribute13  Attribute15  \
# 0      0.615385    0.192308     0.307692     0.096154     0.151515
# 1      0.153846    0.163462     0.153846     0.288462     0.949495
# 2      0.307692    0.413462     0.153846     0.326923     0.212121
# 3      0.461538    0.288462     0.461538     0.250000     0.232323
# 4      0.461538    0.086538     0.461538     0.096154     0.747475
# ..          ...         ...          ...          ...          ...
# 819    0.384615    0.461538     1.000000     0.326923     0.767677
# 820    0.461538    0.182692     0.000000     0.346154     0.515152
# 821    0.461538    0.192308     0.461538     0.326923     0.575758
# 822    0.000000    0.250000     0.461538     0.384615     0.737374
# 823    0.153846    0.230769     0.153846     0.346154     0.505051
#
#      Attribute17  Attribute19  Attribute21  Attribute22
# 0       0.546351        0.125     0.933908          0.0
# 1       0.437870        0.875     0.155172          0.0
# 2       0.564103        0.750     0.821839          0.0
# 3       0.599606        0.500     0.600575          0.0
# 4       0.668639        0.875     0.281609          1.0
# ..           ...          ...          ...          ...
# 819     0.449704        0.750     0.678161          1.0
# 820     0.487179        0.375     0.744253          0.0
# 821     0.483235        0.250     0.729885          0.0
# 822     0.461538        0.875     0.666667          0.0
# 823     0.465483        0.375     0.758621          0.0
#
# [824 rows x 15 columns]

# %%
a0 = t['Attribute22']
a1 = t['Attribute23']
n = 0
for i in range(len(a0)):
    if a0[i] == a1[i]:
        n = n+1
print (n / len(a0))
# Out:
# 0.7661578054629468

# %%
t2 = pd.read_csv('train.csv')
t2 = t2['Attribute22']
n = 0
for i in t2:
    if i == 'No':
        n = n + 1
print (n / len(t2))
# Out:
# 0.7771538866467801
